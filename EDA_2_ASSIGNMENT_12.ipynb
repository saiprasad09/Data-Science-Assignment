# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('/content/adult_with_headers.csv')
data.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
data[data.duplicated(keep=False)] #show duplicate
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 2303    90            Private   52386   Some-college             10
# 3917    19            Private  251579   Some-college             10
# 4325    25            Private  308144      Bachelors             13
# 4767    21            Private  250051   Some-college             10
# 4881    25            Private  308144      Bachelors             13
# 4940    38            Private  207202        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 5579    27            Private  255582        HS-grad              9
# 5805    20            Private  107658   Some-college             10
# 5842    25            Private  195994        1st-4th              2
# 6990    19            Private  138153   Some-college             10
# 7053    49   Self-emp-not-inc   43479   Some-college             10
# 7920    49            Private   31267        7th-8th              4
# ...

# %%
data.drop_duplicates(inplace =True)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32537 entries, 0 to 32536
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education_num   32537 non-null  int64
#  5   marital_status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    32537 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  32537 non-null  object
#  14  income          32537 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital_gain        119
# capital_loss         92
# hours_per_week       94
# native_country       42
# income                2
# dtype: int64

# %%
data['sex'].value_counts()
# Out:
# sex
# Male      21775
# Female    10762
# Name: count, dtype: int64

# %%
# Create a single figure with multiple subplots
fig, axes = plt.subplots(len(data.columns), 1, figsize=(10, len(data.columns) * 5))

# Plot count plots for each categorical column
for i, column in enumerate(data.columns):
    sns.countplot(data=data, x=column, ax=axes[i])
    axes[i].set_title(f'Frequency of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
numerical_columns = data.select_dtypes(include=['number']).columns
for col in numerical_columns:
    plt.figure(figsize=(11, 3))
    plt.hist(data[col], bins=30, edgecolor='k')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
# created copy
data1 = data

# %% [markdown]
# # STANDARD SCALING

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler = StandardScaler()
numeric_cols = data1.select_dtypes(include=['int64', 'float64'])
data_ss= scaler.fit_transform(numeric_cols)
# Convert the scaled data back to a DataFrame
data_ss = pd.DataFrame(data_ss, columns=numeric_cols.columns, index=data.index)
# Replace the original numerical columns with the scaled data
data1[numeric_cols.columns] = data_ss
data1.head()
# Out:
#         age          workclass    fnlwgt   education  education_num  \
# 0  0.030390          State-gov -1.063569   Bachelors       1.134777
# 1  0.836973   Self-emp-not-inc -1.008668   Bachelors       1.134777
# 2 -0.042936            Private  0.245040     HS-grad      -0.420679
# 3  1.056950            Private  0.425752        11th      -1.198407
# 4 -0.776193            Private  1.408066   Bachelors       1.134777
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %% [markdown]
# # Min Max Scaling

# %%
scaler = MinMaxScaler()
data_mm = scaler.fit_transform(numeric_cols)
# Convert the scaled data back to a DataFrame with the same column names
data_mm = pd.DataFrame(data_mm, columns=numeric_cols.columns)
data_mm.head()
# Out:
#         age    fnlwgt  education_num  capital_gain  capital_loss  \
# 0  0.301370  0.044302       0.800000       0.02174           0.0
# 1  0.452055  0.048238       0.800000       0.00000           0.0
# 2  0.287671  0.138113       0.533333       0.00000           0.0
# 3  0.493151  0.151068       0.400000       0.00000           0.0
# 4  0.150685  0.221488       0.800000       0.00000           0.0
#
#    hours_per_week
# 0        0.397959
# 1        0.122449
# 2        0.397959
# 3        0.397959
# 4        0.397959

# %% [markdown]
# # ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
# Identify categorical columns with less than 5 categories
categorical_cols_lt5 = [col for col in data1.select_dtypes(include=['object']).columns if data1[col].nunique() < 4]
# Apply One-Hot Encoding
data1 = pd.get_dummies(data1, columns=categorical_cols_lt5, drop_first=True)

# Identify categorical columns with more than 5 categories in the updated DataFrame
categorical_cols_gt5 = [col for col in data1.select_dtypes(include=['object']).columns if data1[col].nunique() >= 4]

# Initialize the LabelEncoder
label_encoders = {}

# Apply Label Encoding to these columns
for col in categorical_cols_gt5:
    le = LabelEncoder()
    # Fit and transform the column data
    data2[col] = le.fit_transform(data2[col])
    # Save the encoder for inverse transformation if needed
    label_encoders[col] = le
data1.head()
# Out:
#         age  workclass    fnlwgt  education  education_num  marital_status  \
# 0  0.030390          7 -1.063569          9       1.134777               4
# 1  0.836973          6 -1.008668          9       1.134777               2
# 2 -0.042936          4  0.245040         11      -0.420679               0
# 3  1.056950          4  0.425752          1      -1.198407               2
# 4 -0.776193          4  1.408066          9       1.134777               2
#
#    occupation  relationship  race  capital_gain  capital_loss  hours_per_week  \
# 0           1             1     4      0.148292     -0.216743       -0.035664
# 1           4             0     4     -0.145975     -0.216743       -2.222483
# 2           6             1     4     -0.145975     -0.216743       -0.035664
# 3           6             0     2     -0.145975     -0.216743       -0.035664
# 4          10             5     2     -0.145975     -0.216743       -0.035664
#
#    native_country  sex_ Male  income_ >50K
# ...

# %%
# Print unique values and counts for all columns
for col in data1.columns:
    print(f"Column: {col}")
    print(data1[col].value_counts())
    print()
# Out:
# Column: age
# age
# -0.189587    898
# -0.556216    888
# -0.336239    886
# -1.142822    876
# -0.409565    875
#             ...
#  3.256723      6
#  3.623352      3
#  3.403374      3
#  3.476700      1
#  3.550026      1
# Name: count, Length: 73, dtype: int64
#
# Column: workclass
# workclass
# 4    22673
# 6     2540
# 2     2093
# 0     1836
# 7     1298
# 5     1116
# 1      960
# 8       14
# 3        7
# Name: count, dtype: int64
#
# Column: fnlwgt
# fnlwgt
# -0.242441    13
# -0.632561    13
#  0.129858    13
# -0.386395    12
# -0.723954    12
#              ..
# -0.487319     1
# -0.300705     1
#  0.407401     1
#  1.286461     1
#  0.639678     1
# Name: count, Length: 21648, dtype: int64
#
# Column: education
# education
# 11    10494
# 15     7282
# 9      5353
# 12     1722
# 8      1382
# 1      1175
# 7      1067
# 0       933
# 5       645
# 14      576
# 6       514
# 2       433
# 10      413
# 4       332
# 3       166
# 13       50
# ...

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# create.column.age.income.ratio.
# to.capture.the.interaction.between.age.and.weight.

# %%
data1['age_income_ratio'] = data1['age'] / data1['fnlwgt']

# %% [markdown]
# create column capital_gain_loss_ratio
# can help in understanding the relationship between gains and losses. it can be useful in predicting income levels, as individuals with high captial gains and low losses might have different income charaterstics compared to those with the opposite.

# %%
# Handle division by zero
data1['capital_gain_loss_ratio'] = np.where(data1['capital_loss'] == 0,
                                            data1['capital_gain'], data1['capital_gain'] / data1['capital_loss'])

data1.head()
# Out:
#         age  workclass    fnlwgt  education  education_num  marital_status  \
# 0  0.030390          7 -1.063569          9       1.134777               4
# 1  0.836973          6 -1.008668          9       1.134777               2
# 2 -0.042936          4  0.245040         11      -0.420679               0
# 3  1.056950          4  0.425752          1      -1.198407               2
# 4 -0.776193          4  1.408066          9       1.134777               2
#
#    occupation  relationship  race  capital_gain  capital_loss  hours_per_week  \
# 0           1             1     4      0.148292     -0.216743       -0.035664
# 1           4             0     4     -0.145975     -0.216743       -2.222483
# 2           6             1     4     -0.145975     -0.216743       -0.035664
# 3           6             0     2     -0.145975     -0.216743       -0.035664
# 4          10             5     2     -0.145975     -0.216743       -0.035664
#
# ...

# %%
## transformation skewed numerical feature and justify your choice.
from scipy.stats import skew
# Calculate skewness
numerical_cols = data1.select_dtypes(include=['int64', 'float64'])
# Calculate skewness for numerical columns
skewness = numerical_cols.apply(lambda x: skew(x))
print(skewness)
# Out:
# age                         0.557637
# workclass                  -0.751564
# fnlwgt                      1.447636
# education                  -0.934117
# education_num              -0.309486
# marital_status             -0.012752
# occupation                  0.114581
# relationship                0.786512
# race                       -2.435225
# capital_gain               11.948852
# capital_loss                4.592491
# hours_per_week              0.228748
# native_country             -3.660959
# age_income_ratio           74.278125
# capital_gain_loss_ratio   -11.946107
# dtype: float64

# %%
def apply_ufunc(ufunc, method, inputs, kwargs):
    pass

# %%
ufunc = np.add  # Assign a ufunc to the variable
method = 'reduce'  # Assign a valid method
inputs = ([1, 2, 3],)  # Provide inputs
kwargs = {}  # Provide any keyword arguments

result = getattr(ufunc, method)(*inputs, **kwargs)
print(result)  # Output the result
# Out:
# 6

# %%
# Handle NaN values if any
# For simplicity, you might replace NaN with a specific value, e.g., 0 or mean
data1.fillna(0, inplace=True)

# %% [markdown]
# # Feature Selection

# %%
# Use the Isolation Forest algorithm to identify and remove outliers.
from sklearn.ensemble import IsolationForest
iso_forest = IsolationForest(contamination=0.1)
outliers = iso_forest.fit_predict(data1)

# Convert to DataFrame
outliers_df = pd.DataFrame({'Outlier': outliers})
data_with_outliers = pd.concat([data1, outliers_df], axis=1)

# Display the data with outliers marked
print(data_with_outliers)
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.030390          7 -1.063569          9       1.134777
# 1      0.836973          6 -1.008668          9       1.134777
# 2     -0.042936          4  0.245040         11      -0.420679
# 3      1.056950          4  0.425752          1      -1.198407
# 4     -0.776193          4  1.408066          9       1.134777
# ...         ...        ...       ...        ...            ...
# 32532 -0.849519          4  0.639678          7       0.745913
# 32533  0.103716          4 -0.335436         11      -0.420679
# 32534  1.423579          4 -0.358779         11      -0.420679
# 32535 -1.216148          4  0.110930         11      -0.420679
# 32536  0.983625          5  0.929812         11      -0.420679
#
#        marital_status  occupation  relationship  race  capital_gain  \
# 0                   4           1             1     4      0.148292
# 1                   2           4             0     4     -0.145975
# ...

# %%
# Filter out the outliers (rows where 'Outlier' == -1)
data_clean = data_with_outliers[data_with_outliers['Outlier'] != -1].drop(columns=['Outlier'])
data_clean.head()
# Out:
#         age  workclass    fnlwgt  education  education_num  marital_status  \
# 0  0.030390          7 -1.063569          9       1.134777               4
# 1  0.836973          6 -1.008668          9       1.134777               2
# 2 -0.042936          4  0.245040         11      -0.420679               0
# 3  1.056950          4  0.425752          1      -1.198407               2
# 5 -0.116262          4  0.898122         12       1.523641               2
#
#    occupation  relationship  race  capital_gain  capital_loss  hours_per_week  \
# 0           1             1     4      0.148292     -0.216743       -0.035664
# 1           4             0     4     -0.145975     -0.216743       -2.222483
# 2           6             1     4     -0.145975     -0.216743       -0.035664
# 3           6             0     2     -0.145975     -0.216743       -0.035664
# 5           4             5     4     -0.145975     -0.216743       -0.035664
#
# ...

# %%
#pip install pandas==1.5.3

# %%
# !pip install ppscore
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 79.8 MB/s eta 0:00:00
# ...
#   Created wheel for ppscore: filename=ppscore-1.3.0-py2.py3-none-any.whl size=13164 sha256=96f08fd18c0001feb6ab850f39da5787df5ed571c422f038c32f8d8ca047a536
#   Stored in directory: /root/.cache/pip/wheels/42/87/10/00056aa2d2624f1b9374db6a0d5245da9a3d87bdc9247c1a56
# Successfully built ppscore
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# ...

# %%
import ppscore as pps
import pandas as pd  # Import pandas

# %%
data1 = pd.read_csv('/content/adult_with_headers.csv')

# %%
import ppscore as pps
# Calculate the PPS matrix
pps_matrix = pps.matrix(data1)
pps_matrix = pps_matrix.pivot(index='x', columns='y', values='ppscore')

# Display the PPS matrix
print(pps_matrix)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# ...

# %%
corr_matrix = data1.corr()
corr_matrix
# Out:
# <ipython-input-7-58d9ab01b89c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data1.corr()
#                      age    fnlwgt  education_num  capital_gain  capital_loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education_num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital_gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital_loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours_per_week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours_per_week
# age                   0.068756
# fnlwgt               -0.018768
# education_num         0.148123
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt  # Import matplotlib.pyplot as plt

# %%
# Plotting the PPS matrix
plt.figure(figsize=(11, 5))
sns.heatmap(pps_matrix, annot=True, cmap='coolwarm')
plt.title('PPS Matrix')
plt.show()

# %%
# Plotting the correlation matrix
plt.figure(figsize=(11, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
