# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('/content/EastWestAirlines.xlsx', sheet_name='data')
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# min       1.000000       0.000000      0.00000           0.000000
# 25%       1.000000    1250.000000      3.00000           0.000000
# 50%       1.000000    7171.000000     12.00000           0.000000
# 75%       1.000000   23800.500000     17.00000         311.000000
# max       5.000000  263685.000000     86.00000       30817.000000
#
#        Flight_trans_12  Days_since_enroll       Award?
# count      3999.000000         3999.00000  3999.000000
# mean          1.373593         4118.55939     0.370343
# std           3.793172         2065.13454     0.482957
# min           0.000000            2.00000     0.000000
# 25%           0.000000         2330.00000     0.000000
# 50%           0.000000         4096.00000     0.000000
# 75%           1.000000         5790.50000     1.000000
# max          53.000000         8296.00000     1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %% [markdown]
# # DATA PREPROCESSING

# %%
data.isnull().sum() # check the missing values
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
data = data.dropna() # dropping rows with missing values

# %%
# Detecting outliers using Z-score
from scipy import stats

# %%
data_df = data

# %%
z_scores = np.abs(stats.zscore(data_df.select_dtypes(include=[np.number])))
data_df = data_df[(z_scores < 3).all(axis=1)]

# %%
scaler = StandardScaler()  # Creating a StandardScaler object
scaled_features = scaler.fit_transform(data_df.select_dtypes(include=[np.number]))

# %%
# Update the DataFrame with scaled features
data_df_scaled = pd.DataFrame(scaled_features, columns=data_df.select_dtypes(include=[np.number]).columns)

# %%
# Plotting correlation matrix
plt.figure(figsize=(11, 8))
sns.heatmap(data_df_scaled.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Visualizing feature distributions
data_df_scaled.hist(bins=10, figsize=(14, 5), layout=(4, 4))
plt.suptitle('Feature Distributions')
plt.show()

# %% [markdown]
# # Implementing clustering ALGORITHMS:

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# K-Means Clustering
inertia = []
silhouette_scores = []

# %%
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42) # Now KMeans is defined and can be used
    kmeans.fit(data_df_scaled)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(data_df_scaled, kmeans.labels_))

# %%
plt.figure(figsize=(14, 10))
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_df_scaled)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(data_df_scaled, kmeans.labels_))

# %%
plt.plot(list(range(2, 10)))
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.show()

# %%
silhouette_scores = []

# %%
for k in range(4, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_df_scaled)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(data_df_scaled, kmeans.labels_))

# %%
plt.subplot(1, 2, 2)
plt.plot(range(2, 10), silhouette_scores, 'ro-', label='Silhouette Score')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different K')
plt.show()

# %%
# Best K-Means clustering based on Silhouette Score
best_k = silhouette_scores.index(max(silhouette_scores)) + 2
kmeans = KMeans(n_clusters=best_k, random_state=42)
kmeans.fit(data_df_scaled)
kmeans_labels = kmeans.labels_

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
# Hierarchical Clustering
Z = linkage(data_df_scaled, method='ward')
plt.figure(figsize=(10, 8))
dendrogram(Z)
plt.title('Dendrogram for Hierarchical Clustering')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# # cluster analysis

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster # Import fcluster here

# %%
# Assign clusters
hierarchical_labels = fcluster(Z, t=best_k, criterion='maxclust')

# %%
from sklearn.cluster import DBSCAN

# %%
# DBSCAN Clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(data_df_scaled)

# %%
# Evaluate DBSCAN with silhouette score
dbscan_silhouette = silhouette_score(data_df_scaled, dbscan_labels)
print(f'DBSCAN Silhouette Score: {dbscan_silhouette:.3f}')
# Out:
# DBSCAN Silhouette Score: -0.399

# %% [markdown]
# # Visualization

# %%
# Add cluster labels to the dataset
data_df_scaled['KMeans_Cluster'] = kmeans_labels
data_df_scaled['Hierarchical_Cluster'] = hierarchical_labels
data_df_scaled['DBSCAN_Cluster'] = dbscan_labels

# %%
# Analyzing clusters
print("K-Means Cluster Analysis")
print(data_df_scaled.groupby('KMeans_Cluster').mean())
# Out:
# K-Means Cluster Analysis
#                      ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# KMeans_Cluster
# 0               0.249621 -0.387516   -0.049571  -0.614535        0.0
# 1              -0.100947  0.592335    0.481406   0.014163        0.0
# 2              -0.441953  0.593668   -0.010122   1.137754        0.0
#
#                 cc3_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# KMeans_Cluster
# 0                     0.0    -0.569651    -0.520842          -0.250750
# 1                     0.0     0.263982     0.661813           3.032057
# 2                     0.0     1.001431     0.826419          -0.177852
#
#                 Flight_trans_12  Days_since_enroll    Award?  \
# KMeans_Cluster
# 0                     -0.242700          -0.259350 -0.322102
# 1                      2.973064           0.127168  0.602127
# 2                     -0.180279           0.454448  0.470163
#
#                 Hierarchical_Cluster  DBSCAN_Cluster
# KMeans_Cluster
# 0                           1.100638        0.830601
# 1                           2.000000       -1.000000
# 2                           2.583263        0.956044

# %%
print("\nHierarchical Cluster Analysis")
print(data_df_scaled.groupby('Hierarchical_Cluster').mean())
# Out:
# Hierarchical Cluster Analysis
#                            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# Hierarchical_Cluster
# 1                     0.261997 -0.336749    0.041959  -0.496521        0.0
# 2                    -0.026213  0.294432    0.128192  -0.155182        0.0
# 3                    -0.593244  0.664499   -0.144771   1.201285        0.0
#
#                       cc3_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# Hierarchical_Cluster
# 1                           0.0    -0.482617    -0.412047          -0.309911
# 2                           0.0     0.016195     0.353755           2.349534
# 3                           0.0     1.104861     0.815530          -0.169767
#
#                       Flight_trans_12  Days_since_enroll    Award?  \
# Hierarchical_Cluster
# 1                           -0.314137          -0.267939 -0.227585
# 2                            2.349079           0.049868  0.436802
# 3                           -0.159867           0.598032  0.359696
#
#                       KMeans_Cluster  DBSCAN_Cluster
# Hierarchical_Cluster
# 1                           0.211268        0.897447
# 2                           0.746631       -1.000000
# 3                           1.884498        1.049645

# %%
print("\nDBSCAN Cluster Analysis")
print(data_df_scaled.groupby('DBSCAN_Cluster').mean())
# Out:
# DBSCAN Cluster Analysis
#                      ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# DBSCAN_Cluster
# -1             -0.148947  0.453938    0.146908   0.388999        0.0
#  0              0.287999 -0.611324   -0.158869  -0.755664        0.0
#  1             -1.574482  0.736971   -0.158869  -0.755664        0.0
#  2             -0.219212 -0.571228   -0.158869  -0.755664        0.0
#  3             -1.496608 -0.776332   -0.158869   0.002087        0.0
#  4             -1.513330  0.435742   -0.158869   0.759839        0.0
#  5             -0.213342 -0.598777   -0.158869   0.759839        0.0
#  6              0.004412  0.196533   -0.158869   0.759839        0.0
#  7             -0.846779 -0.363397   -0.158869   0.002087        0.0
#  8             -1.036395  0.240128   -0.158869   1.517591        0.0
#  9             -0.906359  0.600927   -0.158869   0.002087        0.0
#  10            -0.975914 -0.482953   -0.158869   1.517591        0.0
#  11            -0.779333 -0.529743   -0.158869   0.002087        0.0
#  12            -0.662143 -0.819878   -0.158869  -0.755664        0.0
#  13            -0.480448  0.610214   -0.158869   1.517591        0.0
#  14             0.525890 -0.229026   -0.158869   0.002087        0.0
#  15            -0.307690  0.011368   -0.158869   1.517591        0.0
#  16            -0.051942 -0.312638   -0.158869   1.517591        0.0
#  17            -0.210154  0.880456   -0.158869   1.517591        0.0
#  18            -0.026066  0.051833   -0.158869   1.517591        0.0
#  19             0.261094 -0.731403   -0.158869   0.002087        0.0
#  20             0.692381 -0.662433   -0.158869  -0.755664        0.0
#  21             0.508640 -0.363504   -0.158869  -0.755664        0.0
#  22             0.689456 -0.431514   -0.158869   1.517591        0.0
#  23             0.688202 -0.785421   -0.158869  -0.755664        0.0
#  24             1.400344 -0.530503   -0.158869  -0.755664        0.0
#  25             1.605644 -0.887857   -0.158869  -0.755664        0.0
#
#                 cc3_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# DBSCAN_Cluster
# -1                    0.0     0.459271     0.442967           0.363765
#  0                    0.0    -0.701919    -0.737071          -0.401822
#  1                    0.0    -0.435577     0.743714          -0.401822
#  2                    0.0    -0.663460    -0.825588          -0.401822
#  3                    0.0    -0.326251     0.367967          -0.401822
#  4                    0.0     0.151235     0.590183          -0.401822
#  5                    0.0     0.157665     0.502217          -0.401822
#  6                    0.0     0.169323     0.424584          -0.401822
#  7                    0.0    -0.415862     0.250798          -0.401822
#  8                    0.0     0.849353     0.560799          -0.401822
#  9                    0.0    -0.290536     0.398269          -0.401822
#  10                   0.0     0.896906     0.509377          -0.401822
#  11                   0.0    -0.291806     0.482442          -0.401822
#  12                   0.0    -0.766025    -1.098658          -0.229416
#  13                   0.0     1.078337     0.569981          -0.401822
#  14                   0.0    -0.352540     0.344880          -0.401822
#  15                   0.0     1.134099     0.331604          -0.401822
#  16                   0.0     1.079559     0.479075          -0.401822
#  17                   0.0     0.901051     0.489176          -0.401822
#  18                   0.0     0.829101     0.489176          -0.401822
#  19                   0.0    -0.272019     0.515149          -0.401822
#  20                   0.0    -0.766101    -1.057830          -0.073406
#  21                   0.0    -0.758568    -0.928966           0.069234
#  22                   0.0     0.799471     0.367967          -0.401822
#  23                   0.0    -0.630660    -0.201714          -0.401822
#  24                   0.0    -0.762232    -1.147142           0.349624
#  25                   0.0    -0.692579    -0.985530          -0.401822
#
#                 Flight_trans_12  Days_since_enroll    Award?  KMeans_Cluster  \
# DBSCAN_Cluster
# -1                     0.387311           0.169662  0.358505        1.117179
#  0                    -0.431775          -0.308894 -0.718093        0.000000
#  1                    -0.431775           1.768568 -0.718093        1.600000
#  2                    -0.431775           0.192327  1.392577        0.000000
#  3                    -0.431775           1.745833  1.392577        2.000000
#  4                    -0.431775           1.477882 -0.718093        2.000000
#  5                    -0.431775           0.175352  1.392577        1.721519
#  6                    -0.431775          -0.039325 -0.718093        1.171053
#  7                    -0.431775           0.762926 -0.718093        0.133333
#  8                    -0.431775           0.993948 -0.718093        2.000000
#  9                    -0.431775           0.827209 -0.718093        1.000000
#  10                   -0.431775           0.935080  1.392577        2.000000
#  11                   -0.431775           0.707755  1.392577        1.555556
#  12                    0.118170           0.636258 -0.718093        0.000000
#  13                   -0.431775           0.515210  1.392577        2.000000
#  14                   -0.431775          -0.563134 -0.718093        0.000000
#  15                   -0.431775           0.320077 -0.718093        2.000000
#  16                   -0.431775           0.028839  1.392577        2.000000
#  17                   -0.431775           0.134314 -0.718093        2.000000
#  18                   -0.431775          -0.042107 -0.718093        2.000000
#  19                   -0.431775          -0.331676  1.392577        0.000000
#  20                    0.118170          -0.646191 -0.718093        0.000000
#  21                    0.668115          -0.545549 -0.718093        0.000000
#  22                   -0.431775          -0.795596  1.392577        2.000000
#  23                   -0.431775          -0.835715  1.392577        0.000000
#  24                    0.118170          -1.388653 -0.718093        0.000000
#  25                   -0.431775          -1.282575  1.392577        0.000000
#
#                 Hierarchical_Cluster
# DBSCAN_Cluster
# -1                          2.020679
#  0                          1.000000
#  1                          1.000000
#  2                          1.000000
#  3                          3.000000
#  4                          3.000000
#  5                          1.784810
#  6                          2.210526
#  7                          1.000000
#  8                          3.000000
#  9                          2.250000
#  10                         3.000000
#  11                         1.000000
#  12                         1.000000
#  13                         3.000000
#  14                         1.000000
#  15                         3.000000
#  16                         3.000000
#  17                         3.000000
#  18                         3.000000
#  19                         1.000000
#  20                         1.000000
#  21                         1.000000
#  22                         3.000000
#  23                         1.000000
#  24                         1.000000
#  25                         1.000000

# %%
# K-Means Clusters
plt.subplot(1, 2, 1)
sns.scatterplot(x=data_df_scaled.iloc[:, 0], y=data_df_scaled.iloc[:, 1], hue=kmeans_labels, palette='Set1')
plt.title('K-Means Clustering')
plt.show()

# %%
# Hierarchical Clusters
plt.subplot(1, 2, 2)
sns.scatterplot(x=data_df_scaled.iloc[:, 0], y=data_df_scaled.iloc[:, 1], hue=hierarchical_labels, palette='Set2')
plt.title('Hierarchical Clustering')
plt.show()

# %%
# DBSCAN Clusters
plt.subplot(1, 3, 3)
sns.scatterplot(x=data_df_scaled.iloc[:, 0], y=data_df_scaled.iloc[:, 1], hue=dbscan_labels, palette='Set3')
plt.title('DBSCAN Clustering')
plt.show()

# %% [markdown]
# # Evaluation

# %%
# Evaluate K-Means Clustering
kmeans_silhouette = silhouette_score(data_df_scaled.iloc[:, :-3], kmeans_labels)
print(f'K-Means Silhouette Score: {kmeans_silhouette:.4f}')
# Out:
# K-Means Silhouette Score: 0.2919

# %%
# Evaluate Hierarchical Clustering
hierarchical_silhouette = silhouette_score(data_df_scaled.iloc[:, :-3], hierarchical_labels)
print(f'Hierarchical Clustering Silhouette Score: {hierarchical_silhouette:.4f}')
# Out:
# Hierarchical Clustering Silhouette Score: 0.2636
